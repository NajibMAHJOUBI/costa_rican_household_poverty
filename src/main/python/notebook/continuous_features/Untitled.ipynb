# %%
import os
import pandas as pd

# %%
path = "../../../../../submission/sklearn/classifier/continuous/"

# %%
all_features = pd.read_csv(os.path.join(path, "all_features.csv"), header=0)

# %%
all_features.head()
# Out:
#    accuracy           classifier        f1  precision    recall
# 0  0.581590            ada_boost  0.416376   0.416429  0.429793
# 1  0.829498        decision_tree  0.752511   0.743849  0.762390
# 2  0.845188        random_forest  0.772744   0.790418  0.758386
# 3  0.562762  logistic_regression  0.373486   0.379822  0.401929
# 4  0.435495    nearest_neighbors  0.301030   0.306426  0.313966

# %%
pearson_features = pd.read_csv(os.path.join(path, "pearson_features.csv"), header=0)

# %%
pearson_features.head(20)
# Out:
#    accuracy              classifier        f1  precision    recall
# 0  0.578103               ada_boost  0.414860   0.410480  0.429065
# 1  0.873780           decision_tree  0.816111   0.809619  0.822936
# 2  0.886332            all_features  0.828811   0.841224  0.818160
# 3  0.541841     logistic_regression  0.378837   0.378113  0.392856
# 4  0.402720       nearest_neighbors  0.293637   0.310110  0.313984
# 5  0.536960             gaussian_nb  0.369255   0.392825  0.380563
# 6  0.153417          mlp_classifier  0.081810   0.659953  0.261879
# 7  0.891562             one_vs_rest  0.838065   0.868257  0.813392
# 8  0.507322  quadratic_discriminant  0.409623   0.415914  0.457237
# 9  0.652371                     svc  0.402331   0.529804  0.376046
